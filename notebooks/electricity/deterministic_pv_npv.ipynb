# %% [markdown]
# # Deterministic PV NPV
#
# Calculate a single PV NPV case using the shared deterministic electricity source code. The notebook displays the representative input values and the processed NPV outputs without duplicating the model formulas.

# %%
from pathlib import Path
import sys

import pandas as pd

PROJECT_ROOT = Path.cwd()
while PROJECT_ROOT != PROJECT_ROOT.parent and not (PROJECT_ROOT / "src").exists():
    PROJECT_ROOT = PROJECT_ROOT.parent

SRC_DIR = PROJECT_ROOT / "src"
if str(SRC_DIR) not in sys.path:
    sys.path.insert(0, str(SRC_DIR))

from electricity.electricity_npv_deterministic import calculate_deterministic_electricity_result

# %%
TECHNOLOGY = "pv"

result = calculate_deterministic_electricity_result(TECHNOLOGY)
value = {key: values[0] for key, values in result.items()}

UNITS = {
    "annual_output_mwh": "MWh/year",
    "full_load_hours_per_year": "h/year",
    "capex_eur_per_kw": "EUR/kW",
    "fixed_opex_eur_per_kw_year": "EUR/kW/year",
    "variable_opex_eur_per_mwh": "EUR/MWh_e",
    "fuel_consumption_mwh_th_per_mwh_e": "MWh_th/MWh_e",
    "emissions_tco2_per_mwh_e": "tCO2/MWh_e",
    "fuel_price_eur_per_mwh_th": "EUR/MWh_th",
    "electricity_price_eur_per_mwh": "EUR/MWh_e",
    "carbon_price_eur_per_t": "EUR/tCO2",
    "capacity_mw": "MW",
    "capacity_kw": "kW",
    "initial_capex_eur": "EUR",
    "annual_revenue_eur": "EUR/year",
    "annual_fixed_opex_eur": "EUR/year",
    "annual_variable_opex_eur": "EUR/year",
    "annual_fuel_cost_eur": "EUR/year",
    "annual_emissions_cost_eur": "EUR/year",
    "annual_total_cost_eur": "EUR/year",
    "annual_net_cash_flow_eur": "EUR/year",
    "npv_eur": "EUR",
    "discounted_lifetime_output_mwh": "MWh",
    "present_value_total_cost_eur": "EUR",
    "lcoe_eur_per_mwh": "EUR/MWh",
    "levelized_net_margin_eur_per_mwh": "EUR/MWh",
}

RAW_INPUT_COLUMNS = (
    "annual_output_mwh",
    "full_load_hours_per_year",
    "capex_eur_per_kw",
    "fixed_opex_eur_per_kw_year",
    "variable_opex_eur_per_mwh",
    "fuel_consumption_mwh_th_per_mwh_e",
    "emissions_tco2_per_mwh_e",
    "fuel_price_eur_per_mwh_th",
    "electricity_price_eur_per_mwh",
    "carbon_price_eur_per_t",
)

PROCESSED_OUTPUT_COLUMNS = (
    "capacity_mw",
    "capacity_kw",
    "initial_capex_eur",
    "annual_revenue_eur",
    "annual_fixed_opex_eur",
    "annual_variable_opex_eur",
    "annual_fuel_cost_eur",
    "annual_emissions_cost_eur",
    "annual_total_cost_eur",
    "annual_net_cash_flow_eur",
    "npv_eur",
    "discounted_lifetime_output_mwh",
    "present_value_total_cost_eur",
    "lcoe_eur_per_mwh",
    "levelized_net_margin_eur_per_mwh",
)

def build_table(columns):
    return pd.DataFrame(
        {
            "parameter": columns,
            "value": [value[column] for column in columns],
            "unit": [UNITS[column] for column in columns],
        }
    )

summary = pd.DataFrame(
    {
        "metric": (
            "Technology",
            "NPV",
            "NPV",
            "LCOE",
            "Levelized net margin",
            "Annual net cash flow",
            "Discounted lifetime output",
        ),
        "value": (
            value["technology"],
            value["npv_eur"],
            value["npv_eur"] / 1_000_000,
            value["lcoe_eur_per_mwh"],
            value["levelized_net_margin_eur_per_mwh"],
            value["annual_net_cash_flow_eur"],
            value["discounted_lifetime_output_mwh"],
        ),
        "unit": (
            "technology key",
            "EUR",
            "MEUR",
            "EUR/MWh",
            "EUR/MWh",
            "EUR/year",
            "MWh",
        ),
    }
)
raw_inputs = build_table(RAW_INPUT_COLUMNS)
processed_outputs = build_table(PROCESSED_OUTPUT_COLUMNS)

# %% [markdown]
# ## Summary

# %%
summary
# Out:
#                        metric             value            unit
# 0                  Technology                pv  technology key
# 1                         NPV  201476998.759699             EUR
# 2                         NPV        201.476999            MEUR
# 3                        LCOE         76.173315         EUR/MWh
# 4        Levelized net margin         17.896685         EUR/MWh
# 5        Annual net cash flow   82060970.654628        EUR/year
# 6  Discounted lifetime output   11257783.343127             MWh

# %% [markdown]
# ## Representative inputs

# %%
raw_inputs
# Out:
#                            parameter       value          unit
# 0                  annual_output_mwh  1000000.00      MWh/year
# 1           full_load_hours_per_year     1107.50        h/year
# 2                   capex_eur_per_kw      800.00        EUR/kW
# 3         fixed_opex_eur_per_kw_year       13.30   EUR/kW/year
# 4          variable_opex_eur_per_mwh        0.00     EUR/MWh_e
# 5  fuel_consumption_mwh_th_per_mwh_e        0.00  MWh_th/MWh_e
# 6           emissions_tco2_per_mwh_e        0.00    tCO2/MWh_e
# 7          fuel_price_eur_per_mwh_th        0.00    EUR/MWh_th
# 8      electricity_price_eur_per_mwh       94.07     EUR/MWh_e
# 9             carbon_price_eur_per_t       80.00      EUR/tCO2

# %% [markdown]
# ## Processed outputs

# %%
processed_outputs
# Out:
#                            parameter         value      unit
# 0                        capacity_mw  9.029345e+02        MW
# 1                        capacity_kw  9.029345e+05        kW
# 2                  initial_capex_eur  7.223476e+08       EUR
# 3                 annual_revenue_eur  9.407000e+07  EUR/year
# 4              annual_fixed_opex_eur  1.200903e+07  EUR/year
# 5           annual_variable_opex_eur  0.000000e+00  EUR/year
# 6               annual_fuel_cost_eur  0.000000e+00  EUR/year
# 7          annual_emissions_cost_eur  0.000000e+00  EUR/year
# 8              annual_total_cost_eur  1.200903e+07  EUR/year
# 9           annual_net_cash_flow_eur  8.206097e+07  EUR/year
# 10                           npv_eur  2.014770e+08       EUR
# 11    discounted_lifetime_output_mwh  1.125778e+07       MWh
# 12      present_value_total_cost_eur  8.575427e+08       EUR
# 13                  lcoe_eur_per_mwh  7.617332e+01   EUR/MWh
# 14  levelized_net_margin_eur_per_mwh  1.789668e+01   EUR/MWh
