# %% [markdown]
# # Deterministic waste heat recovery cement retrofit NPV
#
# Calculate a single waste heat recovery cement retrofit NPV case using the shared deterministic cement source code. The notebook displays the representative input values and the processed NPV outputs without duplicating the model formulas.

# %%
from pathlib import Path
import sys

import pandas as pd

PROJECT_ROOT = Path.cwd()
while PROJECT_ROOT != PROJECT_ROOT.parent and not (PROJECT_ROOT / "src").exists():
    PROJECT_ROOT = PROJECT_ROOT.parent

SRC_DIR = PROJECT_ROOT / "src"
if str(SRC_DIR) not in sys.path:
    sys.path.insert(0, str(SRC_DIR))

from cement.cement_npv_deterministic import calculate_deterministic_cement_result

# %%
TECHNOLOGY = 'waste_heat_recovery'

result = calculate_deterministic_cement_result(TECHNOLOGY)
value = {key: values[0] for key, values in result.items()}

UNITS = {
    "annual_output_t": "t/year",
    "technology_type": "category",
    "capex_eur_per_t": "EUR/t",
    "fixed_opex_eur_per_t": "EUR/t",
    "variable_opex_eur_per_t": "EUR/t",
    "fuel_consumption_mwh_th_per_t": "MWh_th/t",
    "electricity_consumption_mwh_per_t": "MWh/t",
    "emissions_tco2_per_t": "tCO2/t",
    "fuel_price_eur_per_mwh_th": "EUR/MWh_th",
    "electricity_price_eur_per_mwh": "EUR/MWh",
    "cement_price_eur_per_t": "EUR/t",
    "carbon_price_eur_per_t": "EUR/tCO2",
    "capex_change_eur_per_t": "EUR/t",
    "fixed_opex_change_eur_per_t": "EUR/t",
    "variable_opex_change_eur_per_t": "EUR/t",
    "fuel_consumption_reduction_fraction": "fraction",
    "electricity_consumption_reduction_fraction": "fraction",
    "emissions_reduction_fraction": "fraction",
    "initial_capex_eur": "EUR",
    "annual_revenue_eur": "EUR/year",
    "annual_fixed_opex_eur": "EUR/year",
    "annual_variable_opex_eur": "EUR/year",
    "annual_fuel_cost_eur": "EUR/year",
    "annual_electricity_cost_eur": "EUR/year",
    "annual_emissions_cost_eur": "EUR/year",
    "annual_total_cost_eur": "EUR/year",
    "annual_net_cash_flow_eur": "EUR/year",
    "npv_eur": "EUR",
    "discounted_lifetime_output_t": "t",
    "present_value_total_cost_eur": "EUR",
    "lcoc_eur_per_t": "EUR/t",
    "levelized_net_margin_eur_per_t": "EUR/t",
    "npv_million_eur_per_t": "MEUR/t",
}

RAW_INPUT_COLUMNS = (
    "annual_output_t",
    "technology_type",
    "capex_eur_per_t",
    "fixed_opex_eur_per_t",
    "variable_opex_eur_per_t",
    "fuel_consumption_mwh_th_per_t",
    "electricity_consumption_mwh_per_t",
    "emissions_tco2_per_t",
    "fuel_price_eur_per_mwh_th",
    "electricity_price_eur_per_mwh",
    "cement_price_eur_per_t",
    "carbon_price_eur_per_t",
)

RETROFIT_INPUT_COLUMNS = (
    "capex_change_eur_per_t",
    "fixed_opex_change_eur_per_t",
    "variable_opex_change_eur_per_t",
    "fuel_consumption_reduction_fraction",
    "electricity_consumption_reduction_fraction",
    "emissions_reduction_fraction",
)

PROCESSED_OUTPUT_COLUMNS = (
    "initial_capex_eur",
    "annual_revenue_eur",
    "annual_fixed_opex_eur",
    "annual_variable_opex_eur",
    "annual_fuel_cost_eur",
    "annual_electricity_cost_eur",
    "annual_emissions_cost_eur",
    "annual_total_cost_eur",
    "annual_net_cash_flow_eur",
    "npv_eur",
    "discounted_lifetime_output_t",
    "present_value_total_cost_eur",
    "lcoc_eur_per_t",
    "levelized_net_margin_eur_per_t",
    "npv_million_eur_per_t",
)

def build_table(columns):
    selected_columns = [column for column in columns if column in value]
    return pd.DataFrame(
        {
            "parameter": selected_columns,
            "value": [value[column] for column in selected_columns],
            "unit": [UNITS[column] for column in selected_columns],
        }
    )

summary = pd.DataFrame(
    {
        "metric": (
            "Technology",
            "Technology type",
            "NPV",
            "NPV",
            "LCOC",
            "Levelized net margin",
            "Annual net cash flow",
            "Discounted lifetime output",
        ),
        "value": (
            value["technology"],
            value["technology_type"],
            value["npv_eur"],
            value["npv_eur"] / 1_000_000,
            value["lcoc_eur_per_t"],
            value["levelized_net_margin_eur_per_t"],
            value["annual_net_cash_flow_eur"],
            value["discounted_lifetime_output_t"],
        ),
        "unit": (
            "technology key",
            "category",
            "EUR",
            "MEUR",
            "EUR/t",
            "EUR/t",
            "EUR/year",
            "t",
        ),
    }
)
raw_inputs = build_table(RAW_INPUT_COLUMNS)
retrofit_inputs = build_table(RETROFIT_INPUT_COLUMNS)
processed_outputs = build_table(PROCESSED_OUTPUT_COLUMNS)

# %% [markdown]
# ## Summary

# %%
summary
# Out:
#                        metric                value            unit
# 0                  Technology  waste_heat_recovery  technology key
# 1             Technology type             retrofit        category
# 2                         NPV     515690903.710782             EUR
# 3                         NPV           515.690904            MEUR
# 4                        LCOC           101.690706           EUR/t
# 5        Levelized net margin            48.309294           EUR/t
# 6        Annual net cash flow      64234686.666667        EUR/year
# 7  Discounted lifetime output      10674776.188589               t

# %% [markdown]
# ## Expected inputs

# %%
raw_inputs
# Out:
#                             parameter      value        unit
# 0                     annual_output_t  1000000.0      t/year
# 1                     technology_type   retrofit    category
# 2                     capex_eur_per_t      170.0       EUR/t
# 3                fixed_opex_eur_per_t  14.633333       EUR/t
# 4             variable_opex_eur_per_t   5.166667       EUR/t
# 5       fuel_consumption_mwh_th_per_t   0.666667    MWh_th/t
# 6   electricity_consumption_mwh_per_t   0.061967       MWh/t
# 7                emissions_tco2_per_t   0.633333      tCO2/t
# 8           fuel_price_eur_per_mwh_th      12.11  EUR/MWh_th
# 9       electricity_price_eur_per_mwh      116.6     EUR/MWh
# 10             cement_price_eur_per_t      150.0       EUR/t
# 11             carbon_price_eur_per_t       80.0    EUR/tCO2

# %% [markdown]
# ## BAU-relative retrofit inputs

# %%
retrofit_inputs
# Out:
#                                     parameter   value      unit
# 0                      capex_change_eur_per_t  10.000     EUR/t
# 1                 fixed_opex_change_eur_per_t   0.300     EUR/t
# 2              variable_opex_change_eur_per_t   0.000     EUR/t
# 3         fuel_consumption_reduction_fraction   0.000  fraction
# 4  electricity_consumption_reduction_fraction   0.285  fraction
# 5                emissions_reduction_fraction   0.000  fraction

# %% [markdown]
# ## Processed outputs

# %%
processed_outputs
# Out:
#                          parameter         value      unit
# 0                initial_capex_eur  1.700000e+08       EUR
# 1               annual_revenue_eur  1.500000e+08  EUR/year
# 2            annual_fixed_opex_eur  1.463333e+07  EUR/year
# 3         annual_variable_opex_eur  5.166667e+06  EUR/year
# 4             annual_fuel_cost_eur  8.073333e+06  EUR/year
# 5      annual_electricity_cost_eur  7.225313e+06  EUR/year
# 6        annual_emissions_cost_eur  5.066667e+07  EUR/year
# 7            annual_total_cost_eur  8.576531e+07  EUR/year
# 8         annual_net_cash_flow_eur  6.423469e+07  EUR/year
# 9                          npv_eur  5.156909e+08       EUR
# 10    discounted_lifetime_output_t  1.067478e+07         t
# 11    present_value_total_cost_eur  1.085526e+09       EUR
# 12                  lcoc_eur_per_t  1.016907e+02     EUR/t
# 13  levelized_net_margin_eur_per_t  4.830929e+01     EUR/t
